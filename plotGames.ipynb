# %%
include("Games_src.jl")

normalTable=[
    (0,0) (3,-1);
    (-1,3) (2,2)
]
normalform=NormalForm(normalTable)
normalform=randomNormalForm((2,2))
plotall(normalform)
# Out:
#   Activating project at `~/Dropbox/Documents/UBC/teaching/ECON 601/slides/Code programs`
